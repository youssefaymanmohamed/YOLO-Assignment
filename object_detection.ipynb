# %% [markdown]
# # Computer Vision Lab: Object Detection using YoloV5

# %% [markdown]
# ## Setup & Installation

# %% [markdown]
# ### Setup

# %%
# !sudo apt update
# !sudo apt install git   # "if you don't have it"
# !sudo apt install -y python3 python3-pip    # "if you don't have it"

# %% [markdown]
# ###  Clone YOLOv5 Repository

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# c:\Users\youss\OneDrive\Desktop\Term 7\Computer Vision\Assignments\YOLOV5\yolov5
# Cloning into 'yolov5'...

# %% [markdown]
# ### Install YOLOv5 Dependencies

# %%
# !pip install -U -r requirements.txt
# Out:
# ...
#   Using cached numpy-2.2.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...

# %% [markdown]
# ### Directory Structure

# %% [markdown]
# - YOLOv5’s directory structure includes several important folders:
#
#     - data/: Contains datasets and configuration files. For example, data/images/ is where your images should be placed for detection.
#
#     - models/: Includes pre-trained model configurations and weights. You can find YOLOv5 model definitions here, like yolov5s.yaml.
#
#     - runs/: Stores the output of your detection runs. After running detection, the results are saved in directories such as runs/detect/exp/.
#
#     - utils/: Contains utility scripts used by YOLOv5, including functions for parsing arguments, logging, and drawing bounding boxes.
#
#     - data.yaml: A configuration file that defines dataset paths and class names for training and evaluation.
#
#     - detect.py: The main script used for performing object detection. You can run this script with various arguments to detect objects in images or videos.

# %% [markdown]
# ## Object detection using Web Cam

# %%
# !python detect.py --source 0  #change the source number depnding on number of cams
# !python detect.py --weights yolov5x.pt --source 0
# For more info go to detect.py

# %% [markdown]
# ## Model Usage

# %%
import torch
from pathlib import Path
from IPython.display import Image, display
import matplotlib.pyplot as plt

# %%
# Load YOLOv5 model (choose a model size: small 's', medium 'm', large 'l', or extra-large 'x')
model_5s = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or 'yolov5m', 'yolov5l', 'yolov5x'
# Out:
# Using cache found in C:\Users\youss/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-12-21 Python-3.11.7 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
print(model_5s)
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
print(model_5s.names)
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'micr
# ...

# %%
img_path = Path('img1.jpg')

results = model_5s(img_path)

results.show()
# Out:
# C:\Users\youss/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=910x1137>

# %%
# Load YOLOv5 model (choose a model size: small 's', medium 'm', large 'l', or extra-large 'x')
model_5x = torch.hub.load('ultralytics/yolov5', 'yolov5x')  # or 'yolov5m', 'yolov5l', 'yolov5x'

img_path = Path('img2.png')

results = model_5x(img_path)

results.show()
# Out:
# Using cache found in C:\Users\youss/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-12-21 Python-3.11.7 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients, 205.5 GFLOPs
# Adding AutoShape...
# C:\Users\youss/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# Exercise 1: Modify the code to display only specific classes (e.g., only 'person' or 'car') in the detection results.
#
# Exercise 2: (Advanced): Train YOLOv5 on a custom dataset by following the YOLOv5 fine-tuning instructions. Test the trained model on new images.

# %% [markdown]
# ## Exercise 1

# %%
import cv2
import numpy as np

# %%
# Load YOLOv5 model (choose a model size: small 's', medium 'm', large 'l', or extra-large 'x')
model_5s = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or 'yolov5m', 'yolov5l', 'yolov5x'

# Path to the video
video_path = Path('vid1.mp4')

# Open the video file
cap = cv2.VideoCapture(str(video_path))

# Check if the video was opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Define the allowed classes (e.g., 'person', 'car')
allowed_classes = ['person', 'car']

# Process the video frame by frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # Exit the loop if no frames are left

    # Convert the frame to RGB (YOLOv5 uses RGB)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Perform inference on the frame
    results = model_5s(rgb_frame)

    # Get all detections (unfiltered)
    unfiltered_results = results.pandas().xyxy[0]   # 0 is the index of the first frame

    # Create a copy for unfiltered results
    unfiltered_frame = frame.copy() # Copy the frame to draw unfiltered results

    # Draw bounding boxes for unfiltered results
    for _, row in unfiltered_results.iterrows():
        xmin, ymin, xmax, ymax = int(row['xmin']), int(row['ymin']), int(row['xmax']), int(row['ymax']) # Bounding box coordinates
        label = f"{row['name']} {row['confidence']:.2f}" # Label for the bounding box
        color = (255, 0, 0)  # Blue color for unfiltered results
        cv2.rectangle(unfiltered_frame, (xmin, ymin), (xmax, ymax), color, 2) # Draw the bounding box
        cv2.putText(unfiltered_frame, label, (xmin, ymin - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2) # Draw the label

    # Filter results to display only specific classes
    filtered_results = unfiltered_results[unfiltered_results['name'].isin(allowed_classes)] # Filter results by allowed classes

    # Draw bounding boxes for filtered classes
    for _, row in filtered_results.iterrows():
        xmin, ymin, xmax, ymax = int(row['xmin']), int(row['ymin']), int(row['xmax']), int(row['ymax']) # Bounding box coordinates
        label = f"{row['name']} {row['confidence']:.2f}" # Label for the bounding box 
        color = (0, 255, 0)  # Green color for filtered results
        cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), color, 2) # Draw the bounding box 
        cv2.putText(frame, label, (xmin, ymin - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2) # Draw the label

    # Stack both frames side-by-side for comparison
    combined_frame = cv2.vconcat([unfiltered_frame, frame]) # Combine both frames vertically

    # Resize the combined frame to make it smaller (e.g., 50% of original size)
    resized_frame = cv2.resize(combined_frame, None, fx=0.3, fy=0.3, interpolation=cv2.INTER_LINEAR) 

    # Display the resized frame
    cv2.imshow("Unfiltered (up) vs Filtered (down)", resized_frame) # Display the frame

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Using cache found in C:\Users\youss/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-12-21 Python-3.11.7 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# C:\Users\youss/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\youss/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\youss/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %% [markdown]
# ## Exercise 2

# %%
# Train YOLOv5 on a custom dataset by following the YOLOv5 fine-tuning instructions. Test the trained model on new images.

# !python yolov5/train.py --img 416 --batch 16 --epochs 50 --data ./vector/data.yaml --weights yolov5x.pt --device 0
